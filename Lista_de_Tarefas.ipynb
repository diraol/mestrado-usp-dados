# %% [markdown]
# # 1977
# ## Conferir arquivos CSVs que estão na pasta "checks".
# Estes arquivos foram gerados, um para cada variável na qual foi identificada alguma inconformidade (erros/warnings) durante o processamento da base "original" para gerar a nova base reformatada.
#
# Arquivos:
# ### RENFAM
#  [ ] 77_cd_renfam_3.csv
#
#  [ ] 77_cd_renfam_5.csv
# ### RENIND
#  [ ] 77_cd_renind_0.csv
# ### GRAU_INSTR
#  [ ] 77_grau_instr_0.csv
# ### OCUP
#  [ ] 77_ocup_0.csv
# ### SIT_FAM
#  [ ] 77_sit_fam_0.csv
#
#  [ ] 77_sit_fam_9.csv
# ### ORIGEM
#  [ ] 77_mun_orig_0.csv
#
#  [ ] 77_ucod_orig_0.csv
#
#  [ ] 77_ucod_orig_999.csv
#
#  [ ] 77_zona_orig_0.csv
#
#  [ ] 77_zona_orig_999.csv
#
#  [ ] 77_subzona_orig_0.csv
#
#  [ ] 77_subzona_orig_999.csv
# ### DESTINO
#  [ ] 77_mun_dest_0.csv
#
#  [ ] 77_ucod_dest_0.csv
#
#  [ ] 77_ucod_dest_999.csv
#
#  [ ] 77_zona_dest_0.csv
#
#  [ ] 77_zona_dest_999.csv
#
#  [ ] 77_subzona_dest_0.csv
#
#  [ ] 77_subzona_dest_999.csv
# ### ESCOLA
#  [ ] 77_mun_esc_0.csv
#
#  [ ] 77_ucod_esc_0.csv
#
#  [ ] 77_ucod_esc_999.csv
#
#  [ ] 77_zona_esc_0.csv
#
#  [ ] 77_zona_esc_999.csv
#
#  [ ] 77_subzona_esc_0.csv
#
#  [ ] 77_subzona_esc_999.csv
# ### TRABALHO 1
#  [ ] 77_mun_trab1_0.csv
#
#  [ ] 77_ucod_trab1_0.csv
#
#  [ ] 77_ucod_trab1_999.csv
#
#  [ ] 77_zona_trab1_0.csv
#
#  [ ] 77_zona_trab1_999.csv
#
#  [ ] 77_subzona_trab1_0.csv
#
#  [ ] 77_subzona_trab1_999.csv
# ### TRABALHO 2
#  [ ] 77_mun_trab2_0.csv
#
#  [ ] 77_ucod_trab2_0.csv
#
#  [ ] 77_ucod_trab2_999.csv
#
#  [ ] 77_zona_trab2_0.csv
#
#  [ ] 77_zona_trab2_999.csv
#
#  [ ] 77_subzona_trab2_0.csv
#
#  [ ] 77_subzona_trab2_999.csv
