# %% [markdown]
# # Perguntas para a Haydée:
#
# ## Sobre 1977
# ### SEXO
# Estamos substituindo 2 (fem) por 0. mas e os registros que já eram zero inicialmente? Devemos transformá-los em NA antes?

# %% [markdown]
# ### CD_RENFAM
# Eu acho que precisamos fazer uma revisão na lógica que foi utilizada nessa função...
# O resultado da mudança (aplicação da função) foi o seguinte:
#
#              0      1      2      3      5
#         217307   5209   7698    391      1
#
# Quando, pelo que eu entendi, deveria estar na seguinte faixa:
#
# Valor|Descrição
# ----|----
# 0|Renda Familiar Declarada como Zero
# 1|Renda Familiar Declarada e Maior que Zero
# 2|Renda Atribuída

# %% [markdown]
# ## Sobre 1987
# ### Resumo da conversão do código para o formato de 1977
#
# #### Bloco 1 - Funções "gerais"
# Função | Status
# ---------|-------
# consulta_refext | OK
# verifica_dummy | OK
# verifica_range | OK
# passo_corrige_renda | OK
#
# #### Bloco 2 - Funções de variáveis referentes a períodos (dia, horário, etc)
# Função/Variável|Status
# ---------|-------
# passo_ano | OK
# passo_dia_sem | OK
#
# #### Bloco 3 - Funções referentes ao Domicílio
# Função/Variável|Status
# ---------|-------
# passo_zona_dom | OK
# passo_subzona_dom | Verificar
# passo_mun_dom | OK
# passo_tipo_dom | Verificar
# passo_f_dom | OK
# passo_fe_dom | OK
#
# #### Bloco 4 - Funções referentes à Família
# Função/Variável|Status
# ---------|-------
# passo_tot_fam|OK
# passo_f_fam|OK
# passo_fe_fam|OK
# passo_cond_mora|OK
# passo_cd_renfam|Verificar
#
# #### Bloco 5 - Funções referentes à pessoa
# Função/Variável|Status
# --------------|----
# passo_f_pess | OK
# passo_fe_pess | OK
# passo_sit_fam | OK
# passo_idade | OK
# passo_sexo | Verificar
# passo_grau_instr | OK
# passo_ocup | Verificar
# passo_cd_renind | OK
# passo_estuda | OK
# passo_tot_viag | OK
# passo_cd_entre | OK
#
# #### Bloco 6 -  Funções referentes a posses e rendas
# Função/Variável|Status
# -----------------|------
# passo_qt_auto|OK
# passo_qt_bici|Verificar
# passo_qt_moto|Verificar
#
# #### Bloco 7 - Funções referentes Zona, Subzona e Município de uma viagem
# Função/Variável|Status
# --------------|----
# passo_zona_orig | OK
# passo_subzona_orig | Verificar
# passo_mun_orig | OK
# passo_zona_dest | OK
# passo_subzona_dest | Verificar
# passo_mun_dest | OK
# passo_zona_esc | OK
# passo_subzona_esc | Verificar
# passo_mun_esc | OK
# passo_zona_trab1 | OK
# passo_subzona_trab1 | Verificar
# passo_mun_trab1 | OK
# passo_zona_trab2 | OK
# passo_subzona_trab2 | Verificar
# passo_mun_trab2 | OK
#
# #### Bloco 8 - Outras funções referentes a uma viagem
# Função/Variável|Status
# --------------|----
# passo_f_viag | OK
# passo_motivo_orig | OK
# passo_motivo_dest | OK
# passo_modo_1 | OK
# passo_modo2 | OK
# passo_modo3 | OK
# passo_modo4 | OK
# passo_modo_prin | OK
# passo_tipo_est_auto | OK
# passo_valor_est_auto | OK
# passo_dist_viag | OK
#
# #### Bloco 9 - Funções que consultam arquivos externos
# Função/Variável|Status
# --------------|-------
# passo_setor_ativ | OK
# passo_ucod | OK
# passo_coord | OK
#
# #### Bloco 10 - Funções que geram os "NO"s e os "ID"s
# Função/Variável|Status
# --------------|-------
# passo_no_dom|OK
# passo_id_dom|OK
# passo_no_fam|OK
# passo_id_fam|OK
# passo_no_pess|OK
# passo_id_pess|OK
# passo_no_viag|OK
# passo_id_viag|OK

# %% [markdown]
# ### SUBZONAS
#
# Qual a faixa para as subzonas?
# Menor e maior valores para fazermos as verificações....
#
# Nos dados originais da SUBZONA_DOM, a menor é 1 e a maior é 932.
#
# Olhando o conjunto de todas as subzonas (dom, esc, orig, dest, trab1 e trab2), as subzonas vão de: 0 a 1012

# %% [markdown]
# ### Quais as "categorias finais" da variável TIPO_DOM?
#
# Nos dados originais de 1987 temos:
#  * 23 registros com TIPO_DOM igual a zero
#  * 221709 registros com TIPO_DOM igual a um
#  * 2194 registros com TIPO_DOM igual a dois
#
# De acordo com o que estava nos comentários do código que fizemos inicialmente para 1987, o esperado era que os dados estivessem estivessem nas seguintes categorias:
#
# Valor|Descrição
# ----|----
# 1|Individual
# 2|Coletivo
#
# E eles seriam modificados para:
#
# Valor|Descrição
# ----|----
# 0|Particular
# 1|Coletivo
#
#
# Porém, nos comentários do código de 1977 as categorias finais que fizemos foram:
#
# Valor|Descrição
# ----|----
# 0|Não respondeu
# 1|Particular
# 2|Coletivo
#
#
# Fiquei na dúvida qual deve ser o formato final. Eu desconfio que estava descrito errado em 1987.

# %% [markdown]
# ### QT_MOTO e QT_BICI
# Esses dados não foram levantados na OD de 1987. Substituir todos o valor em todos os registros por zero (0)? ou por NA? Ou deixar como está no banco?
#
# Em 1977 substituímos por NA...

# %% [markdown]
# ### SEXO
# Estamos substituindo 2 (fem) por 0. mas e os registros que já eram zero inicialmente? Devemos transformá-los em NA antes?

# %% [markdown]
# ### OCUP
# O que fazer com a variável OCUP em 1987?
# As categorias finais esperadas são, de acordo com o que está comentado nos códigos de 1987 e 1977:
#
# Valor|Descrição
# ----|----
# 1|Tem trabalho
# 2|Em licença médica
# 3|Aposentado / pensionista
# 4|Desempregado
# 5|Sem ocupação
# 6|Dona de casa
# 7|Estudante
#
# Mas não está nos comentários do código quais são as categorias iniciais para 1987.
# No caso de 1977, as categorias iniciais são:
#
# Valor|Descrição
# ----|----
# 1|Estudante
# 2|Prendas Domésticas
# 3|Aposentado
# 4|Sem Ocupação (nunca trabalhou)
# 5|Desempregado
# 6|Em licença
# 7 em diante|diversas profissões
#
# Em 1987, os dados originais seguem a distribuição abaixo:
#
#       0     1     2     3     4     5     6    11    12    13    14    15    16
#     296 45670 32685 10089 21012  5318  1103  8943 12261 13635  6671  3138  2666
#
#      17    18    21    22    23    24    25    26    27    31    32    33    34
#     2526  3842  3360  4506  3676  4454  1365   338    40  6006  5215  2101   718
#
#      35    36    41    42    43    44    45    46    47    51    52    53    54
#     689  1848   934  1829  2170  3190   789   865   602  3347  1627  2984   366
#
#      55    56    57    58    59
#     834    93    68    53     4
#
#
# Para 77 a lógica de "transformação" usada foi:
#  * Somar 10 em todos valores.
#  * Substituir todos valores **10** por **0**
#  * Substituir todos valores **11** por **7**
#  * Substituir todos valores **12** por **6**
#  * Substituir todos valores **13** por **3**
#  * Substituir todos valores **14** por **5**
#  * Substituir todos valores **15** por **4**
#  * Substituir todos valores **16** por **2**
#  * Substituir todos valores *maiores do que 16* por **1**
#
# Isso valerá para 87 se as categorias iniciais forem as mesmas. São? Senão, qual mudança precisa ser feita?

# %% [markdown]
# ### Consulta de Coordenadas
# Qual era mesmo a mágica para consultar o arquivo de "coordenadas"? As SUBZONAS no arquivo de coordenadas de 1987 tem um formato todo bizarro, não lembro qual era a regra de negócio. Ex.:
#
#     "SUBZONA";"zona";"sub_zon";"sub_orig";"CO_X";"CO_Y"
#     1;1;1;001.1;332493.970528;7395758.60297
#     2;1;2;001.2;332149.104916;7394564.03759

# %% [markdown]
# ### CD_RENFAM
# Nos comentários da versão original do código que fizemos está assim:
#
#         Substituir valores da coluna "CD_RENFAM"
#
#         * Substituir todos valores **1** por **0**
#         * Substituir todos valores **3** por **1**
#
#         #### Categorias anteriores
#         Valor|Descrição
#         ----|----
#         1|Não Tem Renda
#         2|Renda Familiar Incompleta
#         3|Renda Familiar Completa
#
#         #### Categorias novas
#         Valor|Descrição
#         ----|----
#         0|Renda Familiar Declarada como Zero
#         1|Renda Familiar Declarada e Maior que Zero
#         2|Renda Atribuída
#
# Me parece meio estranho "Renda Familiar Incompleta" ser transformado em "Renda Atribuída" e "Renda Familiar Completa" ser transformado em "Renda Familiar Declarada e Maior que zero". É isso mesmo?
#
# Além disso, em 1977 nós usamos uma "verificação de força bruta" para melhorar a qualidade dessa variável, basicamente:
#
#         # Quando categoria original for 0 (respondeu) checar no campo REN_FAM
#         #   se o valor é nulo.
#         # Se for nulo, manter na categoria 0 (Renda Fam. Declarada como Zero),
#         #   senão,
#         #   mover para a categoria 1 (Renda Fam. Declarada e Maior que Zero).
#
# Continuamos a utilizar essa lógica, após fazer as substituições indicadas no início (1 por 0 e 3 por 1)?

# %% [markdown]
# # REN_FAN e REN_IND
# Tem que ajustar, na hora de "chamar o passo" qual é o deflator a ser utilizado.
